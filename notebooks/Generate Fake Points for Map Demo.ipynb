# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import os
from src.category_utils import CATIDX_2_FR_CATNAME
from src.db.baserow_db import DetectedDechet, DechetsTable as DB_manager, TABLE_ID_DEMO, TABLE_ID_REAL
import base64

# %% [markdown]
# ## Générer des points autour d'un point de base

# %%
# Après avoir choisie une liste de point (exemple [(41.2564, 1.5), ...] )
base_points = np.array([(48.99983156103193, 1.6841176691599162), (49.00372755154292, 1.7033343932870884),
                        (48.987855683751064, 1.7193594554471827)])

print(base_points)


def display_map(points, red_points=None):
    m = folium.Map(location=(49.00372755154292, 1.7033343932870884), zoom_start=12)

    for point in points:
        folium.Marker(point).add_to(m)

    # red point [1.6919782206738192, 48.99566143128049]
    if red_points is not None:
        for red_point in red_points:
            folium.Marker(red_point, icon=folium.Icon(color='red')).add_to(m)
    return m


display_map(base_points)
# Out:
# [[48.99983156  1.68411767]
#  [49.00372755  1.70333439]
#  [48.98785568  1.71935946]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eee762abcc9841204ce7d5df58225d20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eee762abcc9841204ce7d5df58225d20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eee762abcc9841204ce7d5df58225d20 = L.map(
#                 &quot;map_eee762abcc9841204ce7d5df58225d20&quot;,
#                 {
#                     center: [49.00372755154292, 1.7033343932870884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cffc9a0e0607aab35c8701ae6c1b0b8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cffc9a0e0607aab35c8701ae6c1b0b8e.addTo(map_eee762abcc9841204ce7d5df58225d20);
#
#
#             var marker_2703698639fcf9f9caf02af2fc6de347 = L.marker(
#                 [48.99983156103193, 1.6841176691599162],
#                 {}
#             ).addTo(map_eee762abcc9841204ce7d5df58225d20);
#
#
#             var marker_5d08a471cd02883920e04d786e406c88 = L.marker(
#                 [49.00372755154292, 1.7033343932870884],
#                 {}
#             ).addTo(map_eee762abcc9841204ce7d5df58225d20);
#
#
#             var marker_0246500d00b318132dde435eec4b7990 = L.marker(
#                 [48.987855683751064, 1.7193594554471827],
#                 {}
#             ).addTo(map_eee762abcc9841204ce7d5df58225d20);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(np.array(base_points))
# Out:
# 3

# %%
def generate_points_around_base_point(base_points: list, n_max=50, distance_max=0.01):
    base_points = np.array(base_points)
    reps = n_max // len(base_points)
    points = np.tile(base_points, (reps, 1))
    points += np.random.uniform(-distance_max, distance_max, points.shape)

    # concat and trim
    return np.concatenate([base_points, points])[0:n_max]


points = generate_points_around_base_point(base_points, n_max=75, distance_max=0.01)
points
# Out:
# array([[48.99983156,  1.68411767],
#        [49.00372755,  1.70333439],
#        [48.98785568,  1.71935946],
#        [49.00500672,  1.67616669],
#        [49.00688438,  1.7120198 ],
#        [48.9876648 ,  1.72419847],
#        [49.00627695,  1.68095344],
#        [48.99606705,  1.71070369],
#        [48.98469885,  1.7225492 ],
#        [49.00821955,  1.69050237],
#        [49.01301377,  1.7125959 ],
#        [48.98746356,  1.72786137],
#        [48.99686386,  1.68755414],
#        [48.99868232,  1.69350193],
#        [48.97799701,  1.71885906],
#        [49.0082126 ,  1.69289149],
#        [48.99459129,  1.71046239],
#        [48.98616726,  1.72834574],
#        [49.00441489,  1.69340886],
#        [48.99799851,  1.70305774],
#        [48.99263696,  1.71130398],
#        [49.00130888,  1.67517804],
#        [49.00870883,  1.6979176 ],
#        [48.99439729,  1.72196393],
#        [48.9991428 ,  1.67982474],
#        [49.00133166,  1.71269371],
#        [48.97808231,  1.72568937],
#        [49.00026266,  1.67506491],
#        [49.01232194,  1.69389118],
#        [48.98977324,  1.72030804],
#        [49.00634934,  1.67686117],
#        [48.99439033,  1.70753661],
#        [48.98401876,  1.71668711],
#        [49.00078649,  1.67591613],
#        [49.00822968,  1.71093894],
#        [48.99157015,  1.7185474 ],
#        [48.99345949,  1.68692203],
#        [49.01141244,  1.69660117],
#        [48.98522532,  1.71032207],
#        [49.00801329,  1.68091834],
#        [49.00428439,  1.70507275],
#        [48.97931097,  1.72021936],
#        [48.99544278,  1.67541044],
#        [49.00610481,  1.70188656],
#        [48.98480921,  1.70999334],
#        [48.99357109,  1.6814685 ],
#        [49.01065128,  1.71220739],
#        [48.98427067,  1.714364  ],
#        [49.00086998,  1.67569243],
#        [48.99381761,  1.70146094],
#        [48.99108992,  1.7146007 ],
#        [48.99325014,  1.67605214],
#        [49.00223164,  1.69656825],
#        [48.98200909,  1.72087571],
#        [49.00106665,  1.67535489],
#        [49.01056748,  1.70321569],
#        [48.9967656 ,  1.72409422],
#        [49.00558961,  1.67485635],
#        [48.99425942,  1.69861602],
#        [48.99362424,  1.72784917],
#        [48.99813413,  1.67900196],
#        [48.99805636,  1.70495329],
#        [48.99460338,  1.72790329],
#        [48.99307115,  1.68062211],
#        [49.00789073,  1.7043041 ],
#        [48.98692707,  1.72881197],
#        [48.99093477,  1.68502   ],
#        [49.00577077,  1.69713343],
#        [48.99212049,  1.7178526 ],
#        [49.00652851,  1.67854874],
#        [48.99877282,  1.70271746],
#        [48.98445005,  1.71320494],
#        [49.00207851,  1.67626296],
#        [48.99637135,  1.71188405],
#        [48.98324087,  1.71855516]])

# %%
display_map(points, red_points=base_points)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1649770da65ca611c816d6740d2429b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1649770da65ca611c816d6740d2429b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1649770da65ca611c816d6740d2429b = L.map(
#                 &quot;map_b1649770da65ca611c816d6740d2429b&quot;,
#                 {
#                     center: [49.00372755154292, 1.7033343932870884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70bf57635ff467221a6865a21cf22b58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70bf57635ff467221a6865a21cf22b58.addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_86dce0cc269124df41df06604ea1fef6 = L.marker(
#                 [48.99983156103193, 1.6841176691599162],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_e366cf7a01b922f4c73c2293500f1158 = L.marker(
#                 [49.00372755154292, 1.7033343932870884],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_8f566c5d54dd084de16fff7fc92e8cdc = L.marker(
#                 [48.987855683751064, 1.7193594554471827],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_997aa7d7a3ecdfa80ea960d435439bbd = L.marker(
#                 [49.00500672215289, 1.6761666936057338],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_650dd811c9795f758eacb6ee14e7baab = L.marker(
#                 [49.00688438058364, 1.7120198019757202],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_414778f2f3c75ecb1b518a798b3e638c = L.marker(
#                 [48.987664798206666, 1.724198474434791],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_6f822926e242ddddfecdf407025dd3f2 = L.marker(
#                 [49.00627694562392, 1.680953436415993],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_32526d8ab2b9bc11a655f10114390a3d = L.marker(
#                 [48.99606705412448, 1.7107036925579098],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_b6ed543515aa3b6cdc65a95f1d4f25cb = L.marker(
#                 [48.98469885029712, 1.7225492005856335],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_7977f13c34d58014775be2544125681e = L.marker(
#                 [49.008219547575656, 1.6905023683755864],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_772e366774bdb92bd18c1fc3d7402f40 = L.marker(
#                 [49.013013770455295, 1.7125959000028597],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_b8c4a955c179d3667d9f9c31dc375ec2 = L.marker(
#                 [48.98746355504766, 1.7278613715412399],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_8c4d684c78a733618ceb386f7d86c30e = L.marker(
#                 [48.99686385525623, 1.68755414187517],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_2b56ba29223bc381b3fe0856e85b0229 = L.marker(
#                 [48.998682320698514, 1.6935019288111985],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_4e5e1e1d84f25e7dd6650c88282bcd70 = L.marker(
#                 [48.97799700842555, 1.7188590606906113],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_8ef84635b17414763a31c6b83e6c66a1 = L.marker(
#                 [49.008212601926644, 1.6928914899229446],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_da03eb7287183550d19b3058f5563548 = L.marker(
#                 [48.994591287628175, 1.7104623876781722],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_5d940b5ac959512ab372a99864ade44d = L.marker(
#                 [48.98616725931505, 1.7283457395997635],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);
#
#
#             var marker_d424e08a38864ce287140abc27278386 = L.marker(
#                 [49.0044148853256, 1.6934088566680254],
#                 {}
#             ).addTo(map_b1649770da65ca611c816d6740d2429b);

# %% [markdown]
# ## Ajouter des déchets dans la base de donnée

# %%
def load_data(table_id=TABLE_ID_DEMO):
    db_manager = DB_manager(table_id=table_id)
    data = db_manager.get_list_all_rows()

    return pd.json_normalize(data), db_manager


df_data, dechets_db_manager = load_data(TABLE_ID_DEMO)
df_data
# Out:
#      id                     order                                  name  \
# 0   291    1.00000000000000000000  12b3d8a2-2d23-4de9-8011-035adb7e0c53
# 1   292    2.00000000000000000000  a239f32d-06e3-4888-b001-7a88ed942e70
# 2   293    3.00000000000000000000  a6fe9986-f627-40a1-9c6f-164712437f7a
# 3   294    4.00000000000000000000  0d81989a-ad1b-4675-9d1b-9ff5fa576c40
# 4   295    5.00000000000000000000  e12dc50b-11b4-4a61-892f-345dc696ff02
# ..  ...                       ...                                   ...
# 95  386   96.00000000000000000000  1f36e962-56d7-4271-9a82-034182277ec9
# 96  387   97.00000000000000000000  4a3e5c90-8046-49c4-a267-4d9a68a552dc
# 97  388   98.00000000000000000000  af39109a-85da-44fc-bc54-b65210bb0866
# 98  389   99.00000000000000000000  8c1b8f76-8bd2-4ca6-9288-2da44ae97c7a
# 99  390  100.00000000000000000000  7ef041e6-f33c-44b0-a305-d093e9b2e897
#
#                                                 photo cat_idxs  \
# 0   [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 1   [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 2   [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 3   [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 4   [{'url': 'https://baserow-media.ams3.digitaloc...       []
# ..                                                ...      ...
# 95  [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 96  [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 97  [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 98  [{'url': 'https://baserow-media.ams3.digitaloc...       []
# 99  [{'url': 'https://baserow-media.ams3.digitaloc...       []
#
#               latitude           longitude                 capture_date  \
# 0    48.99983156103193  1.6841176691599162  2024-01-24T21:19:01.536218Z
# 1    49.00372755154292  1.7033343932870884  2024-01-24T21:19:03.111741Z
# 2   48.987855683751064  1.7193594554471827  2024-01-24T21:19:04.615514Z
# 3   48.991733157754254  1.6849784388309088  2024-01-24T21:19:06.282029Z
# 4   49.012860193827656  1.6950186623034529  2024-01-24T21:19:07.757227Z
# ..                 ...                 ...                          ...
# 95   48.97830006839737  1.7094059033556914  2024-01-24T21:21:27.340554Z
# 96   48.99093910367778  1.6809235152498974  2024-01-24T21:21:28.969918Z
# 97   49.00591158174918  1.7029256686200613  2024-01-24T21:21:30.415052Z
# 98   48.99258676389096  1.7189189492484942  2024-01-24T21:21:31.749488Z
# 99   48.99598509102204  1.6768779754453293  2024-01-24T21:21:33.315766Z
#
#    processing_date                                  location description  \
# 0             None   [48.99983156103193, 1.6841176691599162]        None
# 1             None   [49.00372755154292, 1.7033343932870884]        None
# 2             None  [48.987855683751064, 1.7193594554471827]        None
# 3             None  [48.991733157754254, 1.6849784388309088]        None
# 4             None  [49.012860193827656, 1.6950186623034529]        None
# ..             ...                                       ...         ...
# 95            None   [48.97830006839737, 1.7094059033556914]        None
# 96            None   [48.99093910367778, 1.6809235152498974]        None
# 97            None   [49.00591158174918, 1.7029256686200613]        None
# 98            None   [48.99258676389096, 1.7189189492484942]        None
# 99            None   [48.99598509102204, 1.6768779754453293]        None
#
#    uploaded_by                                 cat_idx_occurences  status.id  \
# 0           []                         {"65": 3, "4": 6, "64": 4}    1274759
# 1           []                                 {"48": 4, "24": 1}    1274759
# 2           []                                          {"12": 5}    1274757
# 3           []  {"53": 5, "69": 1, "34": 4, "54": 6, "23": 6, ...    1274757
# 4           []  {"80": 4, "74": 2, "52": 5, "77": 4, "34": 6, ...    1274757
# ..         ...                                                ...        ...
# 95          []                                          {"35": 2}    1274756
# 96          []                {"78": 4, "38": 3, "4": 2, "81": 3}    1274759
# 97          []                                 {"36": 3, "43": 5}    1274756
# 98          []                         {"81": 5, "69": 5, "4": 3}    1274759
# 99          []                                           {"2": 3}    1274756
#
#           status.value status.color
# 0     ✅ Déchet Ramassé        green
# 1     ✅ Déchet Ramassé        green
# 2   ✔️ Déchet Confirmé  dark-orange
# 3   ✔️ Déchet Confirmé  dark-orange
# 4   ✔️ Déchet Confirmé  dark-orange
# ..                 ...          ...
# 95    📍 Déchet Détecté       orange
# 96    ✅ Déchet Ramassé        green
# 97    📍 Déchet Détecté       orange
# 98    ✅ Déchet Ramassé        green
# 99    📍 Déchet Détecté       orange
#
# [100 rows x 16 columns]

# %%
list_status_id = list(dechets_db_manager.status_options_id_dict.keys())
dechets_db_manager.status_options_id_dict
# Out:
# {1274756: '📍 Déchet Détecté',
#  1274757: '✔️ Déchet Confirmé',
#  1274758: '📅 Ramassage Planifié',
#  1274759: '✅ Déchet Ramassé',
#  1274760: '❌ Faux Positif'}

# %% [markdown]
# ## Générer la fausse data complète

# %%
possibles_images: list = glob("../assets/fake_data_photo/*.jpg")

king_dechets = {36: 1.5, 37 : 0.0001, 
                53 : 0.005, 54:0.01,
                59: 0.1, 60: 2, 61:1.2, 62: 0.3, 63: 0.1, 64: 0.6, 65: 0.6, 66: 0.05,
                67: 0.1, 68: 0.2, 69: 0.3, 70: 0.1, 71: 0.2, 72: 0.5, 73: 0.4, 74: 0.2, 75: 0.1, 76: 0.1, 77: 0.5,
                80: 0.5
                }

possibles_cat_idxs = {cat_idx: 1 if cat_idx not in king_dechets.keys() else king_dechets[cat_idx] for cat_idx in
                      CATIDX_2_FR_CATNAME.keys()}
possibles_cat_idxs = {cat_idx: proba / sum(possibles_cat_idxs.values()) for cat_idx, proba in
                      possibles_cat_idxs.items()}  # id and proba

possibles_status: dict = {list_status_id[0]: 0.7, list_status_id[1]: 0.0, list_status_id[2]: 0.25,
                          list_status_id[3]: 0.05, list_status_id[4]: 0.0}  # id and proba 
possibles_status = {status: proba / sum(possibles_status.values()) for status, proba in
                    possibles_status.items()}  # id and proba

# %%
from tqdm import tqdm


def init_fake_data(base_points, possibles_images: dict, possibles_cat_idxs: dict, possibles_status: dict, n_points=75,
                   n_cat_name_max_per_point=8, n_occurence_max_per_cat=6,
                   table_id=TABLE_ID_DEMO
                   ):
    print(">>> Let's generate fake data")
    print(f"* table_id : {table_id}")
    print(f"* base_points : {base_points}")
    print(f"* n_points : {n_points}")
    print(f"* n_cat_name_max_per_point : {n_cat_name_max_per_point}")
    print(f"* n_occurence_max_per_cat : {n_occurence_max_per_cat}")

    points = generate_points_around_base_point(base_points, n_max=n_points, distance_max=0.01)
    # delete all rows
    dechets_db_manager = DB_manager(table_id=table_id)
    dechets_db_manager.delete_all_rows(confirmation=True)
    # Pour chaque point, on va générer un faux déchet
    for point in tqdm(list(points), desc=f"Generating fake data (n={n_points}) [{table_id}]"):
        latitude, longitude = point
        image_path = np.random.choice(possibles_images)
        cat_idxs = random.choices(list(possibles_cat_idxs.keys()), weights=list(possibles_cat_idxs.values()),
                                  k=np.random.randint(1, n_cat_name_max_per_point))

        cat_idx_occurences = {cat_idx: random.randint(1, n_occurence_max_per_cat) for cat_idx in cat_idxs}
        status = np.random.choice(list(possibles_status.keys()), p=list(possibles_status.values()))

        r_added = dechets_db_manager.add_dechet_row(image=image_path,
                                                     cat_idx_occurences=cat_idx_occurences,
                                                     longitude=str(longitude),
                                                     latitude=str(latitude),
                                                     status=status,
                                                     generate_description=False,
                                                     verbose=False,
                                                     )
    print("Done")
    return points


init_fake_data(base_points, possibles_images, possibles_cat_idxs, possibles_status, n_points=160,n_cat_name_max_per_point=8, n_occurence_max_per_cat=7)
# Out:
# >>> Let's generate fake data
# * table_id : 246046
# * base_points : [[48.99983156  1.68411767]
#  [49.00372755  1.70333439]
#  [48.98785568  1.71935946]]
# * n_points : 150
# * n_cat_name_max_per_point : 8
# * n_occurence_max_per_cat : 7
# Found 100 rows.
# Deleted.
# Generating fake data (n=150) [246046]: 100%|██████████| 150/150 [06:39<00:00,  2.66s/it]
# Done
# array([[48.99983156,  1.68411767],
#        [49.00372755,  1.70333439],
#        [48.98785568,  1.71935946],
#        [49.0051825 ,  1.69270549],
#        [48.99445375,  1.71116172],
#        [48.99247522,  1.70953646],
#        [49.00782929,  1.69295158],
#        [49.00194033,  1.69821802],
#        [48.98342552,  1.72317384],
#        [49.00799482,  1.68290746],
#        [49.00944542,  1.71322104],
#        [48.98129519,  1.72080022],
#        [49.00749775,  1.68868841],
#        [49.01288877,  1.70882189],
#        [48.99696028,  1.72537981],
#        [49.00607568,  1.68705885],
#        [49.00003938,  1.70995555],
#        [48.99464698,  1.72604147],
#        [49.00101198,  1.67914087],
#        [49.00839629,  1.70200602],
#        [48.9789459 ,  1.71376923],
#        [48.99354865,  1.67693756],
#        [48.99729978,  1.70646464],
#        [48.98678287,  1.72577012],
#        [48.99085919,  1.6892939 ],
#        [48.99442561,  1.70515447],
#        [48.99442726,  1.72081597],
#        [49.00132815,  1.69026704],
#        [48.99885515,  1.69805587],
#        [48.99242958,  1.71029789],
#        [48.99290151,  1.68175347],
#        [49.00642959,  1.70560539],
#        [48.9929776 ,  1.71622801],
#        [49.00846857,  1.68797172],
#        [48.99826352,  1.69664565],
#        [48.98276113,  1.711525  ],
#        [49.00716645,  1.68017736],
#        [48.9961144 ,  1.69917394],
#        [48.99175846,  1.71873247],
#        [49.00780366,  1.68215578],
#        [49.00984061,  1.70429178],
#        [48.98666708,  1.71475536],
#        [49.00749619,  1.68327269],
#        [48.99785428,  1.71097138],
#        [48.99132092,  1.72655772],
#        [49.00107303,  1.6909371 ],
#        [49.00188459,  1.69728262],
#        [48.97860639,  1.71968944],
#        [49.00299592,  1.6783536 ],
#        [49.00690082,  1.71019193],
#        [48.98629351,  1.71381375],
#        [49.00075381,  1.69372288],
#        [49.01297458,  1.71300308],
#        [48.98222213,  1.71128476],
#        [49.00579333,  1.68014237],
#        [48.99479061,  1.69664009],
#        [48.97845669,  1.71240452],
#        [48.99692271,  1.6761642 ],
#        [49.00441909,  1.709922  ],
#        [48.98148168,  1.7194207 ],
#        [48.98987412,  1.68853968],
#        [49.01092734,  1.70520469],
#        [48.99755946,  1.7156443 ],
#        [49.00378193,  1.67423021],
#        [49.00155089,  1.69384196],
#        [48.98611549,  1.71532652],
#        [49.00742936,  1.67590315],
#        [49.01075218,  1.71088951],
#        [48.98647929,  1.72429538],
#        [48.9996475 ,  1.68367634],
#        [49.01234434,  1.70842708],
#        [48.98849952,  1.71864378],
#        [48.99163904,  1.69334001],
#        [49.00478246,  1.7045402 ],
#        [48.98896935,  1.71919633],
#        [49.00961214,  1.68554365],
#        [48.99533112,  1.70922876],
#        [48.98470805,  1.72682218],
#        [49.00561605,  1.68601696],
#        [48.99430199,  1.6998092 ],
#        [48.98692623,  1.72657576],
#        [49.00374954,  1.68989492],
#        [49.0136109 ,  1.69410304],
#        [48.990511  ,  1.71737282],
#        [48.99675455,  1.67956924],
#        [48.99714439,  1.70680392],
#        [48.99591921,  1.71091612],
#        [48.99111845,  1.68887785],
#        [48.99746674,  1.71025923],
#        [48.98543594,  1.72321601],
#        [49.0096168 ,  1.67953124],
#        [49.0094377 ,  1.71029612],
#        [48.99064788,  1.71413497],
#        [49.00541797,  1.67610282],
#        [49.01070067,  1.69341054],
#        [48.9878047 ,  1.71457614],
#        [48.99009549,  1.68157547],
#        [49.00923461,  1.70819774],
#        [48.98478315,  1.72561908],
#        [48.99336879,  1.68119709],
#        [48.99906603,  1.69550205],
#        [48.98446706,  1.72737601],
#        [49.00876984,  1.67487684],
#        [49.01043532,  1.69817214],
#        [48.98605313,  1.71751959],
#        [49.00338501,  1.68801228],
#        [48.99876797,  1.70746998],
#        [48.98558682,  1.71039484],
#        [49.00611193,  1.6936708 ],
#        [49.01148695,  1.70134316],
#        [48.98500063,  1.72060489],
#        [48.99529886,  1.68614278],
#        [49.00594304,  1.69625532],
#        [48.99158822,  1.72822783],
#        [48.99228541,  1.6841077 ],
#        [49.00174492,  1.70240202],
#        [48.99307412,  1.72529825],
#        [48.99954405,  1.69062035],
#        [48.99451677,  1.70389801],
#        [48.99366726,  1.72729006],
#        [48.99769933,  1.69095793],
#        [49.00077003,  1.70795121],
#        [48.98890919,  1.71917126],
#        [48.99631091,  1.68983264],
#        [49.00829698,  1.69778883],
#        [48.97842851,  1.72320621],
#        [49.00035306,  1.68697416],
#        [49.01342788,  1.70297244],
#        [48.99347699,  1.71741104],
#        [49.00039134,  1.67689755],
#        [48.99632139,  1.70603374],
#        [48.98314554,  1.72038755],
#        [49.00696912,  1.67517309],
#        [48.99683685,  1.70714125],
#        [48.99176774,  1.71813238],
#        [49.00611369,  1.68946691],
#        [49.00313129,  1.70504956],
#        [48.99660097,  1.72688059],
#        [49.00045295,  1.67470919],
#        [48.99982887,  1.70157902],
#        [48.99463371,  1.7110987 ],
#        [48.99059993,  1.69337375],
#        [49.00736764,  1.71207687],
#        [48.99429024,  1.71104554],
#        [49.00428314,  1.6861958 ],
#        [49.00025515,  1.70627187],
#        [48.99001416,  1.715213  ],
#        [48.99019973,  1.68570358],
#        [49.00488293,  1.69683143],
#        [48.9968805 ,  1.71275467]])

# %% [markdown]
# ### afficher les nouvelles données ajoutées

# %%
df_data, _ = load_data(TABLE_ID_DEMO)
df_data
# Out:
#       id                     order                                  name  \
# 0    391    1.00000000000000000000  a8f8eed3-0047-4421-a955-53c901a10305
# 1    392    2.00000000000000000000  d76202dd-1d8f-4f64-a424-a4a669f5d849
# 2    393    3.00000000000000000000  8350b1f4-ab12-4c86-891a-31b1683540d8
# 3    394    4.00000000000000000000  d8dfb34a-aaf0-4983-a1c7-82b51b7e4b38
# 4    395    5.00000000000000000000  a41c9574-43bd-4994-8a89-055eac39ff6e
# ..   ...                       ...                                   ...
# 145  536  146.00000000000000000000  4028ac37-7531-40aa-b370-3928c66b2bbd
# 146  537  147.00000000000000000000  a248b914-df94-4d6e-8daa-1a4b1109591d
# 147  538  148.00000000000000000000  21cc7bb2-fa09-4df7-9b42-f069b71b0470
# 148  539  149.00000000000000000000  ebba179c-68ee-4fe3-8559-c0baea252565
# 149  540  150.00000000000000000000  4beba621-ef0f-480f-8cb6-4c1335cbab55
#
#                                                  photo  \
# 0    [{'url': 'https://baserow-media.ams3.digitaloc...
# 1    [{'url': 'https://baserow-media.ams3.digitaloc...
# 2    [{'url': 'https://baserow-media.ams3.digitaloc...
# 3    [{'url': 'https://baserow-media.ams3.digitaloc...
# 4    [{'url': 'https://baserow-media.ams3.digitaloc...
# ..                                                 ...
# 145  [{'url': 'https://baserow-media.ams3.digitaloc...
# 146  [{'url': 'https://baserow-media.ams3.digitaloc...
# 147  [{'url': 'https://baserow-media.ams3.digitaloc...
# 148  [{'url': 'https://baserow-media.ams3.digitaloc...
# 149  [{'url': 'https://baserow-media.ams3.digitaloc...
#
#                                               cat_idxs            latitude  \
# 0    [{'id': 2, 'value': '1'}, {'id': 36, 'value': ...   48.99983156103193
# 1    [{'id': 23, 'value': '22'}, {'id': 59, 'value'...   49.00372755154292
# 2    [{'id': 35, 'value': '34'}, {'id': 47, 'value'...  48.987855683751064
# 3    [{'id': 8, 'value': '7'}, {'id': 20, 'value': ...   49.00518249950187
# 4    [{'id': 2, 'value': '1'}, {'id': 4, 'value': '...  48.994453745950175
# ..                                                 ...                 ...
# 145  [{'id': 2, 'value': '1'}, {'id': 6, 'value': '...   49.00025515263553
# 146  [{'id': 1, 'value': '0'}, {'id': 35, 'value': ...   48.99001415544647
# 147                        [{'id': 21, 'value': '20'}]   48.99019972760179
# 148  [{'id': 3, 'value': '2'}, {'id': 27, 'value': ...  49.004882930545755
# 149  [{'id': 26, 'value': '25'}, {'id': 61, 'value'...   48.99688050340425
#
#               longitude                 capture_date processing_date  \
# 0    1.6841176691599162  2024-02-08T02:31:36.886225Z            None
# 1    1.7033343932870884  2024-02-08T02:31:38.846131Z            None
# 2    1.7193594554471827  2024-02-08T02:31:40.929777Z            None
# 3     1.692705486027613  2024-02-08T02:31:42.523243Z            None
# 4    1.7111617211909618  2024-02-08T02:31:44.243276Z            None
# ..                  ...                          ...             ...
# 145  1.7062718651114095  2024-02-08T02:38:04.473087Z            None
# 146  1.7152129994461018  2024-02-08T02:38:07.026852Z            None
# 147   1.685703582141655  2024-02-08T02:38:08.825942Z            None
# 148   1.696831427384268  2024-02-08T02:38:10.826963Z            None
# 149  1.7127546682886485  2024-02-08T02:38:12.954490Z            None
#
#                                      location description uploaded_by  \
# 0     [48.99983156103193, 1.6841176691599162]        None          []
# 1     [49.00372755154292, 1.7033343932870884]        None          []
# 2    [48.987855683751064, 1.7193594554471827]        None          []
# 3      [49.00518249950187, 1.692705486027613]        None          []
# 4    [48.994453745950175, 1.7111617211909618]        None          []
# ..                                        ...         ...         ...
# 145   [49.00025515263553, 1.7062718651114095]        None          []
# 146   [48.99001415544647, 1.7152129994461018]        None          []
# 147    [48.99019972760179, 1.685703582141655]        None          []
# 148   [49.004882930545755, 1.696831427384268]        None          []
# 149   [48.99688050340425, 1.7127546682886485]        None          []
#
#                                     cat_idx_occurences  status.id  \
# 0         {"50": 6, "36": 7, "44": 5, "1": 4, "35": 6}    1274756
# 1                          {"58": 3, "79": 4, "22": 1}    1274756
# 2                          {"57": 4, "46": 5, "34": 5}    1274756
# 3    {"33": 1, "19": 7, "66": 6, "60": 6, "7": 6, "...    1274756
# 4    {"30": 3, "23": 1, "33": 7, "9": 3, "1": 1, "3...    1274756
# ..                                                 ...        ...
# 145                          {"46": 5, "1": 3, "5": 5}    1274759
# 146                         {"81": 5, "0": 7, "34": 7}    1274756
# 147                                          {"20": 3}    1274756
# 148       {"55": 1, "70": 3, "26": 5, "46": 6, "2": 4}    1274756
# 149      {"60": 7, "73": 4, "25": 3, "65": 5, "81": 6}    1274758
#
#              status.value status.color
# 0        📍 Déchet Détecté       orange
# 1        📍 Déchet Détecté       orange
# 2        📍 Déchet Détecté       orange
# 3        📍 Déchet Détecté       orange
# 4        📍 Déchet Détecté       orange
# ..                    ...          ...
# 145      ✅ Déchet Ramassé        green
# 146      📍 Déchet Détecté       orange
# 147      📍 Déchet Détecté       orange
# 148      📍 Déchet Détecté       orange
# 149  📅 Ramassage Planifié   light-pink
#
# [150 rows x 16 columns]

# %%
points = df_data[['latitude', 'longitude']].values
display_map(points)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bdcd1f82428b4a25476e4f7deadce8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bdcd1f82428b4a25476e4f7deadce8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bdcd1f82428b4a25476e4f7deadce8b = L.map(
#                 &quot;map_7bdcd1f82428b4a25476e4f7deadce8b&quot;,
#                 {
#                     center: [49.00372755154292, 1.7033343932870884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc80c6b120c734290f548a6189a6b1a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc80c6b120c734290f548a6189a6b1a4.addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_eb4a222af2a3b243a5590e888fbec315 = L.marker(
#                 [48.99983156103193, 1.6841176691599162],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_8f3b21a122ce4acc48519b97174346f6 = L.marker(
#                 [49.00372755154292, 1.7033343932870884],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_59219914f9afffa9eb3a857313433604 = L.marker(
#                 [48.987855683751064, 1.7193594554471827],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_56670c99b2e5c3e682818131eecdd4a4 = L.marker(
#                 [49.00518249950187, 1.692705486027613],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_cd36aabcc40e5607ef2cba182a1057cd = L.marker(
#                 [48.994453745950175, 1.7111617211909618],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_2f48918100b30db5264b20c4d8ffbe46 = L.marker(
#                 [48.99247522258727, 1.7095364565821378],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_cb96d7424f246609be0a3c86e8562385 = L.marker(
#                 [49.00782929372349, 1.6929515793574492],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_8469b087aa422d88c2812e8516dd189e = L.marker(
#                 [49.001940333897444, 1.6982180237497382],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_3c1c48416b2fb3f0993a14b4ae902dd4 = L.marker(
#                 [48.98342552463196, 1.7231738353131316],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_18b63ebee01570b7d2fbf6a8c8a087d7 = L.marker(
#                 [49.0079948173669, 1.6829074555182573],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_38edb598c1a0f28f999f6ebf788a2f98 = L.marker(
#                 [49.009445415537805, 1.713221041769194],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_bca27f19ea0a26262be284ddb966e0a8 = L.marker(
#                 [48.98129519001886, 1.7208002242753135],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_efe30dec77212b2514e62fe1b24130be = L.marker(
#                 [49.007497745751095, 1.6886884087755012],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_179ac6a78493e0daa34bd140d452ab83 = L.marker(
#                 [49.01288876780611, 1.7088218855801873],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_d82b96be8a1a7c53c62b855d9739549e = L.marker(
#                 [48.99696028381194, 1.7253798118297803],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_7a295a4fdbf0f386a2981e94835f53c4 = L.marker(
#                 [49.00607568221222, 1.6870588491719438],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_ae461ae9e3a689a705d8af2afaeb674b = L.marker(
#                 [49.00003937640195, 1.7099555546300187],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_2fdf8f54b31b076f32d190a01d8e6adc = L.marker(
#                 [48.99464697909725, 1.7260414699022184],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);
#
#
#             var marker_db5c18f8ad31eb389893f53f08952b98 = L.marker(
#                 [49.00101198224035, 1.6791408673952102],
#                 {}
#             ).addTo(map_7bdcd1f82428b4a25476e4f7deadce8b);

# %%
m = folium.Map(location=[48.9907, 1.7102], zoom_start=13)

marker_cluster = MarkerCluster().add_to(m)

for i, row_item in df_data.iterrows():
    id_ = row_item['id']
    lat = row_item['latitude']
    long = row_item['longitude']
    print(lat, long)
    photo_url = row_item['photo'][0]['url'] if len(row_item['photo']) > 0 else None
    date = row_item['capture_date']
    status = row_item['status.value']
    status_color = row_item['status.color']
    description = row_item['description']
    if 'cat_idx_occurences' in row_item:
        try:

            cat_idx_occurences = eval(row_item['cat_idx_occurences'])
        except:
            cat_idx_occurences = {}
        else:
            cat_idx_occurences = {int(k): int(v) for k, v in cat_idx_occurences.items()}

    sum_cat_idx_occurences = sum(cat_idx_occurences.values())
    if lat is None or long is None:
        continue
    h4_text = f"{sum_cat_idx_occurences} déchet(s) détecté(s)"

    # crop image to square, 150px
    popup_html = f"""<div>
                            <img src="{photo_url}" width="150" height="100" style="display:block;margin:auto;"><br>
                            <b>Date de capture:</b> {date}<br>
                            <b>Status:</b> {status}<br>
                            <b>Description:</b> {description}
                        </div>
                    """

    iframe = folium.IFrame(popup_html, width=200, height=250)
    #popup = folium.Popup(iframe, max_width=300)
    icon = folium.Icon(color=status_color, icon='trash')
    folium.Marker([lat, long]).add_to(marker_cluster)
    if i > 20:
        break

m
# Out:
# 49.0038842828264 1.6840392821199135
# 49.012331760973225 1.7008874847627227
# 48.984377895216895 1.7203930565672996
# 48.990766836328184 1.6765977325127834
# 49.0122040151781 1.6953912800951436
# 48.99213579922791 1.7273191024775363
# 49.001902972259295 1.6780466396762945
# 49.008733758037096 1.7122044259444105
# 48.978129928257964 1.728921980091218
# 49.00830271307917 1.6855142830375245
# 49.010781100744175 1.6987582117113291
# 48.98061720924831 1.7124753613329378
# 49.00017483533106 1.6894220951698748
# 49.00149844354568 1.7095323994020926
# 48.97907866681826 1.7135816529316044
# C:\Users\CYTech Student\AppData\Local\Temp\ipykernel_2580\1638419640.py:40: UserWarning: color argument of Icon should be one of: {'purple', 'black', 'pink', 'darkgreen', 'beige', 'orange', 'darkpurple', 'darkblue', 'lightgray', 'lightblue', 'blue', 'lightgreen', 'red', 'lightred', 'cadetblue', 'darkred', 'white', 'gray', 'green'}.
#   icon = folium.Icon(color=status_color, icon='trash')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf69e18d7ef51dc4392e276e869f5911 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf69e18d7ef51dc4392e276e869f5911&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf69e18d7ef51dc4392e276e869f5911 = L.map(
#                 &quot;map_cf69e18d7ef51dc4392e276e869f5911&quot;,
#                 {
#                     center: [48.9907, 1.7102],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de8d27cb35ee6f3ae088319c17ec5e4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_de8d27cb35ee6f3ae088319c17ec5e4d.addTo(map_cf69e18d7ef51dc4392e276e869f5911);
#
#
#             var marker_cluster_89a6750cc79cc218587e53276bbd17e5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_261d8f7e9f647622939fbeef7e982492 = L.marker(
#                 [49.0038842828264, 1.6840392821199135],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_33bb03f651255e90735f1c36bf4ceab0 = L.marker(
#                 [49.012331760973225, 1.7008874847627227],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_afad42427e6682cf27dff55d6509e96b = L.marker(
#                 [48.984377895216895, 1.7203930565672996],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_e266893b7221fc95e861ab47819a7eb4 = L.marker(
#                 [48.990766836328184, 1.6765977325127834],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_b14511ad432245c93e46e19081924fd1 = L.marker(
#                 [49.0122040151781, 1.6953912800951436],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_f69ccd576a8d6012a5a08bba1012b71d = L.marker(
#                 [48.99213579922791, 1.7273191024775363],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_cce5a26fe7239b21aa17dbf3fd4e4560 = L.marker(
#                 [49.001902972259295, 1.6780466396762945],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_a30dbc5fd0134fb73a78884230e263c4 = L.marker(
#                 [49.008733758037096, 1.7122044259444105],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_4b0fa562413acc59d89cd4e3fe035928 = L.marker(
#                 [48.978129928257964, 1.728921980091218],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_24596a81e2d5473ba63e3c11e5d84183 = L.marker(
#                 [49.00830271307917, 1.6855142830375245],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_105e54733cd785a17fffbf397b06293d = L.marker(
#                 [49.010781100744175, 1.6987582117113291],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_49ad710d954ee3c7af827f0f241eb5bb = L.marker(
#                 [48.98061720924831, 1.7124753613329378],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_efc30c8a9f6d9a3075527021c20f8572 = L.marker(
#                 [49.00017483533106, 1.6894220951698748],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_ffa39ee071f266b28de9c9ea2b69a0c7 = L.marker(
#                 [49.00149844354568, 1.7095323994020926],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             var marker_244ae38a287c8537b9b2083ac79a39f6 = L.marker(
#                 [48.97907866681826, 1.7135816529316044],
#                 {}
#             ).addTo(marker_cluster_89a6750cc79cc218587e53276bbd17e5);
#
#
#             marker_cluster_89a6750cc79cc218587e53276bbd17e5.addTo(map_cf69e18d7ef51dc4392e276e869f5911);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="p

# %%
df_data_real = load_data(TABLE_ID_REAL)
# long lat to float 
df_data_real['longitude'] = df_data_real['longitude'].astype(float)
df_data_real['latitude'] = df_data_real['latitude'].astype(float)
df_data_real
# Out:
#       id                     order                                  name  \
# 0     66    1.00000000000000000000  5a6c1df8-72e6-4244-9591-d4c7b8495858
# 1     67    2.00000000000000000000  e6068891-4f9c-403e-b9ee-3d025787c78e
# 2     68    3.00000000000000000000  d418863e-cbb5-4805-89bf-1e678a0b1121
# 3     69    4.00000000000000000000  8d8d4a90-aece-41fe-9fff-f6a910b8c6ee
# 4     70    5.00000000000000000000  f054a1ac-976e-4f87-9871-96785b57f6f7
# ..   ...                       ...                                   ...
# 109  175  110.00000000000000000000  f2046863-3509-4588-9b71-1913c948ff06
# 110  176  111.00000000000000000000  476fa07c-2be9-4af0-93af-0df72c08ecbe
# 111  177  112.00000000000000000000  dab1e583-0af7-4c4e-94d4-5ad4b65f5dbf
# 112  178  113.00000000000000000000  5f83f9fc-82e4-4155-b95a-054c1e2ca601
# 113  179  114.00000000000000000000  c8188048-43ca-4e55-ab15-ce3f9fe7baca
#
#                                                  photo  \
# 0    [{'url': 'https://baserow-media.ams3.digitaloc...
# 1    [{'url': 'https://baserow-media.ams3.digitaloc...
# 2    [{'url': 'https://baserow-media.ams3.digitaloc...
# 3    [{'url': 'https://baserow-media.ams3.digitaloc...
# 4    [{'url': 'https://baserow-media.ams3.digitaloc...
# ..                                                 ...
# 109  [{'url': 'https://baserow-media.ams3.digitaloc...
# 110  [{'url': 'https://baserow-media.ams3.digitaloc...
# 111  [{'url': 'https://baserow-media.ams3.digitaloc...
# 112  [{'url': 'https://baserow-media.ams3.digitaloc...
# 113  [{'url': 'https://baserow-media.ams3.digitaloc...
#
#                                               cat_idxs   latitude  longitude  \
# 0                                                   []   1.674655  48.990726
# 1                            [{'id': 7, 'value': '6'}]   1.697409  49.013100
# 2    [{'id': 41, 'value': '40'}, {'id': 50, 'value'...   1.726495  48.986095
# 3    [{'id': 22, 'value': '21'}, {'id': 29, 'value'...   1.690684  48.992280
# 4    [{'id': 20, 'value': '19'}, {'id': 24, 'value'...   1.707056  49.007635
# ..                                                 ...        ...        ...
# 109  [{'id': 8, 'value': '7'}, {'id': 9, 'value': '...   1.691978  48.995661
# 110  [{'id': 8, 'value': '7'}, {'id': 9, 'value': '...   1.691979  48.995663
# 111                                                 []   1.691979  48.995661
# 112                                                 []  48.995667   1.692020
# 113                                                 []  48.995595   1.692028
#
#                     capture_date processing_date  \
# 0    2024-01-24T10:09:14.520772Z            None
# 1    2024-01-24T10:09:16.775595Z            None
# 2    2024-01-24T10:09:18.721834Z            None
# 3    2024-01-24T10:09:20.549467Z            None
# 4    2024-01-24T10:09:22.222185Z            None
# ..                           ...             ...
# 109  2024-01-24T14:22:37.847251Z            None
# 110  2024-01-24T14:23:06.797523Z            None
# 111  2024-01-24T14:30:58.040632Z            None
# 112  2024-01-24T14:36:22.298182Z            None
# 113  2024-01-24T14:37:57.799028Z            None
#
#                                     location description uploaded_by  \
# 0    [1.6746545558850943, 48.99072638869668]        None          []
# 1      [1.697408862262514, 49.0130995585845]        None          []
# 2    [1.7264952512610603, 48.98609506624167]        None          []
# 3    [1.6906839372447227, 48.99228034224054]        None          []
# 4    [1.7070559481233003, 49.00763526562619]        None          []
# ..                                       ...         ...         ...
# 109   [1.6919777043702737, 48.9956606661885]        None          []
# 110  [1.691979030192789, 48.995663039918014]        None          []
# 111  [1.6919790587217478, 48.99566063007205]        None          []
# 112   [48.9956669835525, 1.6920204700629506]        None          []
# 113   [48.99559525726393, 1.692027653882299]        None          []
#
#                        cat_idx_occurences  status.id          status.value  \
# 0                               {"68": 3}    1266082      📍 Déchet Détecté
# 1                       {"6": 4, "81": 1}    1267691  📅 Ramassage Planifié
# 2    {"62": 3, "40": 4, "49": 5, "64": 3}    1266081      ✅ Déchet Ramassé
# 3             {"21": 2, "28": 4, "42": 4}    1267691  📅 Ramassage Planifié
# 4    {"19": 4, "48": 4, "23": 2, "64": 5}    1266081      ✅ Déchet Ramassé
# ..                                    ...        ...                   ...
# 109                      {"7": 1, "8": 1}    1266082      📍 Déchet Détecté
# 110                      {"7": 1, "8": 1}    1266082      📍 Déchet Détecté
# 111                             {"60": 2}    1266082      📍 Déchet Détecté
# 112                             {"60": 1}    1266082      📍 Déchet Détecté
# 113                             {"60": 1}    1266082      📍 Déchet Détecté
#
#     status.color
# 0         orange
# 1     light-pink
# 2          green
# 3     light-pink
# 4          green
# ..           ...
# 109       orange
# 110       orange
# 111       orange
# 112       orange
# 113       orange
#
# [114 rows x 16 columns]

# %%
# get all rows with wrons long lat values (if long > lat)
df_data_real_wrong_long_lat = df_data_real[df_data_real['longitude'] > df_data_real['latitude']]
df_data_real_wrong_long_lat
# Out:
#       id                     order                                  name  \
# 0     66    1.00000000000000000000  5a6c1df8-72e6-4244-9591-d4c7b8495858
# 1     67    2.00000000000000000000  e6068891-4f9c-403e-b9ee-3d025787c78e
# 2     68    3.00000000000000000000  d418863e-cbb5-4805-89bf-1e678a0b1121
# 3     69    4.00000000000000000000  8d8d4a90-aece-41fe-9fff-f6a910b8c6ee
# 4     70    5.00000000000000000000  f054a1ac-976e-4f87-9871-96785b57f6f7
# ..   ...                       ...                                   ...
# 107  173  108.00000000000000000000  37e17279-af3b-4ba1-ae7a-4e4c9664e924
# 108  174  109.00000000000000000000  7e64dda8-4809-490f-9d4d-5bdc8cb997ed
# 109  175  110.00000000000000000000  f2046863-3509-4588-9b71-1913c948ff06
# 110  176  111.00000000000000000000  476fa07c-2be9-4af0-93af-0df72c08ecbe
# 111  177  112.00000000000000000000  dab1e583-0af7-4c4e-94d4-5ad4b65f5dbf
#
#                                                  photo  \
# 0    [{'url': 'https://baserow-media.ams3.digitaloc...
# 1    [{'url': 'https://baserow-media.ams3.digitaloc...
# 2    [{'url': 'https://baserow-media.ams3.digitaloc...
# 3    [{'url': 'https://baserow-media.ams3.digitaloc...
# 4    [{'url': 'https://baserow-media.ams3.digitaloc...
# ..                                                 ...
# 107  [{'url': 'https://baserow-media.ams3.digitaloc...
# 108  [{'url': 'https://baserow-media.ams3.digitaloc...
# 109  [{'url': 'https://baserow-media.ams3.digitaloc...
# 110  [{'url': 'https://baserow-media.ams3.digitaloc...
# 111  [{'url': 'https://baserow-media.ams3.digitaloc...
#
#                                               cat_idxs  latitude  longitude  \
# 0                                                   []  1.674655  48.990726
# 1                            [{'id': 7, 'value': '6'}]  1.697409  49.013100
# 2    [{'id': 41, 'value': '40'}, {'id': 50, 'value'...  1.726495  48.986095
# 3    [{'id': 22, 'value': '21'}, {'id': 29, 'value'...  1.690684  48.992280
# 4    [{'id': 20, 'value': '19'}, {'id': 24, 'value'...  1.707056  49.007635
# ..                                                 ...       ...        ...
# 107                        [{'id': 18, 'value': '17'}]  1.691978  48.995663
# 108  [{'id': 18, 'value': '17'}, {'id': 39, 'value'...  1.691976  48.995662
# 109  [{'id': 8, 'value': '7'}, {'id': 9, 'value': '...  1.691978  48.995661
# 110  [{'id': 8, 'value': '7'}, {'id': 9, 'value': '...  1.691979  48.995663
# 111                                                 []  1.691979  48.995661
#
#                     capture_date processing_date  \
# 0    2024-01-24T10:09:14.520772Z            None
# 1    2024-01-24T10:09:16.775595Z            None
# 2    2024-01-24T10:09:18.721834Z            None
# 3    2024-01-24T10:09:20.549467Z            None
# 4    2024-01-24T10:09:22.222185Z            None
# ..                           ...             ...
# 107  2024-01-24T14:21:02.633810Z            None
# 108  2024-01-24T14:22:05.865995Z            None
# 109  2024-01-24T14:22:37.847251Z            None
# 110  2024-01-24T14:23:06.797523Z            None
# 111  2024-01-24T14:30:58.040632Z            None
#
#                                     location description uploaded_by  \
# 0    [1.6746545558850943, 48.99072638869668]        None          []
# 1      [1.697408862262514, 49.0130995585845]        None          []
# 2    [1.7264952512610603, 48.98609506624167]        None          []
# 3    [1.6906839372447227, 48.99228034224054]        None          []
# 4    [1.7070559481233003, 49.00763526562619]        None          []
# ..                                       ...         ...         ...
# 107  [1.6919783436638178, 48.99566293835541]        None          []
# 108   [1.69197603294245, 48.995662195688496]        None          []
# 109   [1.6919777043702737, 48.9956606661885]        None          []
# 110  [1.691979030192789, 48.995663039918014]        None          []
# 111  [1.6919790587217478, 48.99566063007205]        None          []
#
#                        cat_idx_occurences  status.id          status.value  \
# 0                               {"68": 3}    1266082      📍 Déchet Détecté
# 1                       {"6": 4, "81": 1}    1267691  📅 Ramassage Planifié
# 2    {"62": 3, "40": 4, "49": 5, "64": 3}    1266081      ✅ Déchet Ramassé
# 3             {"21": 2, "28": 4, "42": 4}    1267691  📅 Ramassage Planifié
# 4    {"19": 4, "48": 4, "23": 2, "64": 5}    1266081      ✅ Déchet Ramassé
# ..                                    ...        ...                   ...
# 107           {"17": 5, "61": 1, "72": 1}    1266082      📍 Déchet Détecté
# 108  {"17": 3, "38": 2, "74": 2, "77": 2}    1266082      📍 Déchet Détecté
# 109                      {"7": 1, "8": 1}    1266082      📍 Déchet Détecté
# 110                      {"7": 1, "8": 1}    1266082      📍 Déchet Détecté
# 111                             {"60": 2}    1266082      📍 Déchet Détecté
#
#     status.color
# 0         orange
# 1     light-pink
# 2          green
# 3     light-pink
# 4          green
# ..           ...
# 107       orange
# 108       orange
# 109       orange
# 110       orange
# 111       orange
#
# [112 rows x 16 columns]

# %%
ids_wrong_long_lat = df_data_real_wrong_long_lat['id'].values
ids_wrong_long_lat
# Out:
# array([ 66,  67,  68,  69,  70,  71,  72,  73,  74,  75,  76,  77,  78,
#         79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,
#         92,  93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104,
#        105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117,
#        118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130,
#        131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143,
#        144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156,
#        157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169,
#        170, 171, 172, 173, 174, 175, 176, 177], dtype=int64)

# %%
# change lat <-> long    in the db 
for i, row_item in df_data_real_wrong_long_lat.iterrows():
    id_ = row_item['id']
    lat = row_item['latitude']
    long = row_item['longitude']
    if lat < long:
        dechets_db_manager.update_row(id_=id_, data={'latitude': long, 'longitude': lat})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # change lat <-> long    in the db
# ----> 2 for i, row_item in df_data_real_wrong_long_lat.iterrows():
#       3     id_ = row_item['id']
#       4     lat = row_item['latitude']
#
# NameError: name 'df_data_real_wrong_long_lat' is not defined
