# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

from src.privacy.blur import blur_image
# Out:
# N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\src\weights/ego_blur_face.jit

# %%
from src.weights.utils import get_weights_list

get_weights_list("jit")
# Out:
# ['N:\\My Drive\\KESKIA Drive Mlamali\\Mantes-Plus-Propre\\src\\weights\\ego_blur_face.jit',
#  'N:\\My Drive\\KESKIA Drive Mlamali\\Mantes-Plus-Propre\\src\\weights\\ego_blur_lp.jit']

# %%
image_path = "N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\images_demo\egoblur_demo\img_4.png"
image = Image.open(image_path)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x630>

# %%
out_image_path = blur_image(image_path)
out_image = Image.open(out_image_path)
out_image
# Out:
# >>> Blurring image N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\images_demo\egoblur_demo\img_4.png...
# python ego_blur.py --face_model_path "N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\src\weights/ego_blur_face.jit" --lp_model_path "N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\src\weights/ego_blur_lp.jit" --input_image_path "N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\images_demo\egoblur_demo\img_4.png" --output_image_path "N:\My Drive\KESKIA Drive Mlamali\Mantes-Plus-Propre\images_demo\egoblur_demo\img_4_blurred.png" --face_model_score_threshold 0.7 --lp_model_score_threshold 0.5 --nms_iou_threshold 0.3 --scale_factor_detections 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 out_image_path = blur_image(image_path)
# ----> 2 out_image = Image.open(out_image_path)
#       3 out_image
#
# ...
